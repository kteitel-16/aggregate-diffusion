# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue May  6 12:23:49 2025

@author: ottocordero
"""
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.ndimage import gaussian_filter
from datetime import datetime

# ===========================================
# ------------ PARAMETERS -------------------
# ===========================================

GRID_SIZE = 400

# Initial densities
INITIAL_GREEN_DENSITY = 0.0005
INITIAL_RED_DENSITY = 0.0045

# Substrate and product concentrations
SUBSTRATE_INIT = 100.0
PRODUCT_INIT = 0.0

# Enzyme kinetics
KM = 0.05
ENZYME_INIT = 1.0
MAX_ENZYME_ACTIVITY = 0.1

# Growth kinetics (Monod-type)
GROWTH_RATE_PER_HOUR = np.log(2)
GROWTH_KM = 0.1

# Diffusion (Gaussian)
SUBSTRATE_DIFFUSION_SIGMA = 1.0
PRODUCT_DIFFUSION_SIGMA = 1.0

# ===========================================
# ------------ INITIALIZATION ----------------
# ===========================================

# Create timestamped output directory
timestamp = datetime.now().strftime("run_%Y-%m-%d_%H-%M-%S")
output_dir = os.path.join("simulation_outputs", timestamp)
os.makedirs(output_dir, exist_ok=True)

folders = {
    "images_cells": os.path.join(output_dir, "images_cells"),
    "csv_cells": os.path.join(output_dir, "csv_cells"),
    "images_product": os.path.join(output_dir, "images_product"),
    "csv_product": os.path.join(output_dir, "csv_product"),
}

for f in folders.values():
    os.makedirs(f, exist_ok=True)
    
# -----------------------------
# Save simulation parameters to README
# -----------------------------
readme_path = os.path.join(output_dir, "README.txt")

with open(readme_path, "w") as f:
    f.write("Simulation Parameters\n")
    f.write("=====================\n\n")
    f.write(f"GRID_SIZE = {GRID_SIZE}\n\n")

    f.write("Initial densities\n")
    f.write(f"  INITIAL_GREEN_DENSITY = {INITIAL_GREEN_DENSITY}\n")
    f.write(f"  INITIAL_RED_DENSITY = {INITIAL_RED_DENSITY}\n\n")

    f.write("Substrate and product concentrations\n")
    f.write(f"  SUBSTRATE_INIT = {SUBSTRATE_INIT}\n")
    f.write(f"  PRODUCT_INIT = {PRODUCT_INIT}\n\n")

    f.write("Enzyme kinetics\n")
    f.write(f"  KM = {KM}\n")
    f.write(f"  ENZYME_INIT = {ENZYME_INIT}\n")
    f.write(f"  MAX_ENZYME_ACTIVITY = {MAX_ENZYME_ACTIVITY}\n\n")

    f.write("Growth kinetics (Monod-type)\n")
    f.write(f"  GROWTH_RATE_PER_HOUR = {GROWTH_RATE_PER_HOUR}\n")
    f.write(f"  GROWTH_KM = {GROWTH_KM}\n\n")

    f.write("Diffusion (Gaussian filter sigmas)\n")
    f.write(f"  SUBSTRATE_DIFFUSION_SIGMA = {SUBSTRATE_DIFFUSION_SIGMA}\n")
    f.write(f"  PRODUCT_DIFFUSION_SIGMA = {PRODUCT_DIFFUSION_SIGMA}\n\n")

    f.write("Stopping criteria\n")
    f.write("  Simulation stops at cell density = 0.25\n")

print(f"README.txt written to {readme_path}")

# Initialize grids
grid = np.zeros((GRID_SIZE, GRID_SIZE), dtype=int)
substrate = np.full((GRID_SIZE, GRID_SIZE), SUBSTRATE_INIT, dtype=float)
product = np.full((GRID_SIZE, GRID_SIZE), PRODUCT_INIT, dtype=float)
enzyme_level = np.zeros((GRID_SIZE, GRID_SIZE), dtype=float)

green_cells = np.random.rand(GRID_SIZE, GRID_SIZE) < INITIAL_GREEN_DENSITY
red_cells = (np.random.rand(GRID_SIZE, GRID_SIZE) < INITIAL_RED_DENSITY) & (~green_cells)

grid[green_cells] = 2
grid[red_cells] = 1
enzyme_level[green_cells] = ENZYME_INIT

# Visualization scaling
product_global_max = 1e-6

# ---------- Save initial state ----------
frame = 0
pd.DataFrame(grid).to_csv(f"{folders['csv_cells']}/frame_{frame:04d}_cells.csv", index=False, header=False)
pd.DataFrame(product).to_csv(f"{folders['csv_product']}/frame_{frame:04d}_product.csv", index=False, header=False)

vis = np.zeros((GRID_SIZE, GRID_SIZE, 3), dtype=np.uint8)
vis[grid == 1] = [255, 0, 0]
vis[grid == 2] = [0, 255, 0]
plt.imsave(f"{folders['images_cells']}/frame_{frame:04d}_cells.png", vis)

plt.imsave(f"{folders['images_product']}/frame_{frame:04d}_product.png", product, cmap='Greys', vmin=0, vmax=product_global_max)

frame += 1

# ===========================================
# ------------ SIMULATION LOOP ---------------
# ===========================================

while np.mean(grid > 0) < 0.25:

    # Substrate breakdown
    vmax = enzyme_level * MAX_ENZYME_ACTIVITY
    rate = vmax * substrate / (KM + substrate)
    substrate -= rate
    product += rate
    substrate = np.clip(substrate, 0, None)

    # Diffusion
    product = gaussian_filter(product, sigma=PRODUCT_DIFFUSION_SIGMA)
    substrate = gaussian_filter(substrate, sigma=SUBSTRATE_DIFFUSION_SIGMA)

    product_global_max = max(product_global_max, product.max())

    # Cell growth
    new_grid = grid.copy()
    new_enzyme = enzyme_level.copy()

    for cell_type in [1, 2]:
        positions = np.argwhere(grid == cell_type)
        np.random.shuffle(positions)

        for i, j in positions:
            prod = product[i, j]
            grow_prob = GROWTH_RATE_PER_HOUR * prod / (GROWTH_KM + prod)

            if np.random.rand() < grow_prob:
                neighbors = [(i + di, j + dj) for di in [-1, 0, 1] for dj in [-1, 0, 1]
                             if not (di == 0 and dj == 0)]
                neighbors = [(ni % GRID_SIZE, nj % GRID_SIZE) for ni, nj in neighbors]
                empty_neighbors = [p for p in neighbors if grid[p] == 0]

                if empty_neighbors:
                    ni, nj = empty_neighbors[np.random.randint(len(empty_neighbors))]
                    new_grid[ni, nj] = cell_type

                    if cell_type == 2:
                        new_enzyme[i, j] /= 2
                        new_enzyme[ni, nj] = new_enzyme[i, j]

    grid = new_grid
    enzyme_level = new_enzyme

    # Save
    pd.DataFrame(grid).to_csv(f"{folders['csv_cells']}/frame_{frame:04d}_cells.csv", index=False, header=False)
    pd.DataFrame(product).to_csv(f"{folders['csv_product']}/frame_{frame:04d}_product.csv", index=False, header=False)

    vis = np.zeros((GRID_SIZE, GRID_SIZE, 3), dtype=np.uint8)
    vis[grid == 1] = [255, 0, 0]
    vis[grid == 2] = [0, 255, 0]
    plt.imsave(f"{folders['images_cells']}/frame_{frame:04d}_cells.png", vis)

    plt.imsave(f"{folders['images_product']}/frame_{frame:04d}_product.png", product, cmap='Greys', vmin=0, vmax=product_global_max)

    print(f"Frame {frame:04d} complete. Cell density: {np.mean(grid > 0):.3f}")
    frame += 1
# Out:
# README.txt written to simulation_outputs/run_2026-02-04_09-23-34/README.txt
# Frame 0001 complete. Cell density: 0.005
# Frame 0002 complete. Cell density: 0.005
# Frame 0003 complete. Cell density: 0.005
# Frame 0004 complete. Cell density: 0.005
# Frame 0005 complete. Cell density: 0.005
# Frame 0006 complete. Cell density: 0.005
# Frame 0007 complete. Cell density: 0.005
# Frame 0008 complete. Cell density: 0.005
# Frame 0009 complete. Cell density: 0.006
# Frame 0010 complete. Cell density: 0.006
# Frame 0011 complete. Cell density: 0.006
# Frame 0012 complete. Cell density: 0.006
# Frame 0013 complete. Cell density: 0.007
# Frame 0014 complete. Cell density: 0.007
# Frame 0015 complete. Cell density: 0.008
# Frame 0016 complete. Cell density: 0.008
# Frame 0017 complete. Cell density: 0.009
# Frame 0018 complete. Cell density: 0.009
# Frame 0019 complete. Cell density: 0.010
# Frame 0020 complete. Cell density: 0.011
# Frame 0021 complete. Cell density: 0.012
# Frame 0022 complete. Cell density: 0.013
# Frame 0023 complete. Cell density: 0.014
# Frame 0024 complete. Cell density: 0.015
# Frame 0025 complete. Cell density: 0.016
# Frame 0026 complete. Cell density: 0.017
# Frame 0027 complete. Cell density: 0.018
# Frame 0028 complete. Cell density: 0.020
# Frame 0029 complete. Cell density: 0.021
# Frame 0030 complete. Cell density: 0.022
# Frame 0031 complete. Cell density: 0.024
# Frame 0032 complete. Cell density: 0.025
# Frame 0033 complete. Cell density: 0.027
# Frame 0034 complete. Cell density: 0.028
# Frame 0035 complete. Cell density: 0.030
# Frame 0036 complete. Cell density: 0.031
# Frame 0037 complete. Cell density: 0.033
# Frame 0038 complete. Cell density: 0.034
# Frame 0039 complete. Cell density: 0.036
# Frame 0040 complete. Cell density: 0.038
# Frame 0041 complete. Cell density: 0.040
# Frame 0042 complete. Cell density: 0.041
# Frame 0043 complete. Cell density: 0.043
# Frame 0044 complete. Cell density: 0.045
# Frame 0045 complete. Cell density: 0.047
# Frame 0046 complete. Cell density: 0.048
# Frame 0047 complete. Cell density: 0.050
# Frame 0048 complete. Cell density: 0.052
# Frame 0049 complete. Cell density: 0.054
# Frame 0050 complete. Cell density: 0.055
# Frame 0051 complete. Cell density: 0.057
# Frame 0052 complete. Cell density: 0.059
# Frame 0053 complete. Cell density: 0.061
# Frame 0054 complete. Cell density: 0.063
# Frame 0055 complete. Cell density: 0.065
# Frame 0056 complete. Cell density: 0.067
# Frame 0057 complete. Cell density: 0.069
# Frame 0058 complete. Cell density: 0.070
# Frame 0059 complete. Cell density: 0.072
# Frame 0060 complete. Cell density: 0.074
# Frame 0061 complete. Cell density: 0.076
# Frame 0062 complete. Cell density: 0.078
# Frame 0063 complete. Cell density: 0.080
# Frame 0064 complete. Cell density: 0.082
# Frame 0065 complete. Cell density: 0.084
# Frame 0066 complete. Cell density: 0.086
# Frame 0067 complete. Cell density: 0.088
# Frame 0068 complete. Cell density: 0.090
# Frame 0069 complete. Cell density: 0.091
# Frame 0070 complete. Cell density: 0.093
# Frame 0071 complete. Cell density: 0.095
# Frame 0072 complete. Cell density: 0.097
# Frame 0073 complete. Cell density: 0.099
# Frame 0074 complete. Cell density: 0.101
# Frame 0075 complete. Cell density: 0.103
# Frame 0076 complete. Cell density: 0.105
# Frame 0077 complete. Cell density: 0.107
# Frame 0078 complete. Cell density: 0.109
# Frame 0079 complete. Cell density: 0.111
# Frame 0080 complete. Cell density: 0.113
# Frame 0081 complete. Cell density: 0.115
# Frame 0082 complete. Cell density: 0.117
# Frame 0083 complete. Cell density: 0.119
# Frame 0084 complete. Cell density: 0.121
# Frame 0085 complete. Cell density: 0.123
# Frame 0086 complete. Cell density: 0.125
# Frame 0087 complete. Cell density: 0.127
# Frame 0088 complete. Cell density: 0.129
# Frame 0089 complete. Cell density: 0.131
# Frame 0090 complete. Cell density: 0.133
# Frame 0091 complete. Cell density: 0.135
# Frame 0092 complete. Cell density: 0.137
# Frame 0093 complete. Cell density: 0.139
# Frame 0094 complete. Cell density: 0.141
# Frame 0095 complete. Cell density: 0.143
# Frame 0096 complete. Cell density: 0.144
# Frame 0097 complete. Cell density: 0.146
# Frame 0098 complete. Cell density: 0.148
# Frame 0099 complete. Cell density: 0.150
# Frame 0100 complete. Cell density: 0.152
# Frame 0101 complete. Cell density: 0.154
# Frame 0102 complete. Cell density: 0.156
# Frame 0103 complete. Cell density: 0.158
# Frame 0104 complete. Cell density: 0.160
# Frame 0105 complete. Cell density: 0.162
# Frame 0106 complete. Cell density: 0.164
# Frame 0107 complete. Cell density: 0.166
# Frame 0108 complete. Cell density: 0.168
# Frame 0109 complete. Cell density: 0.170
# Frame 0110 complete. Cell density: 0.172
# Frame 0111 complete. Cell density: 0.174
# Frame 0112 complete. Cell density: 0.176
# Frame 0113 complete. Cell density: 0.178
# Frame 0114 complete. Cell density: 0.180
# Frame 0115 complete. Cell density: 0.182
# Frame 0116 complete. Cell density: 0.184
# Frame 0117 complete. Cell density: 0.186
# Frame 0118 complete. Cell density: 0.188
# Frame 0119 complete. Cell density: 0.190
# Frame 0120 complete. Cell density: 0.191
# Frame 0121 complete. Cell density: 0.194
# Frame 0122 complete. Cell density: 0.196
# Frame 0123 complete. Cell density: 0.198
# Frame 0124 complete. Cell density: 0.200
# Frame 0125 complete. Cell density: 0.202
# Frame 0126 complete. Cell density: 0.204
# Frame 0127 complete. Cell density: 0.206
# Frame 0128 complete. Cell density: 0.208
# Frame 0129 complete. Cell density: 0.210
# Frame 0130 complete. Cell density: 0.212
# Frame 0131 complete. Cell density: 0.214
# Frame 0132 complete. Cell density: 0.215
# Frame 0133 complete. Cell density: 0.217
# Frame 0134 complete. Cell density: 0.219
# Frame 0135 complete. Cell density: 0.221
# Frame 0136 complete. Cell density: 0.223
# Frame 0137 complete. Cell density: 0.225
# Frame 0138 complete. Cell density: 0.227
# Frame 0139 complete. Cell density: 0.229
# Frame 0140 complete. Cell density: 0.231
# Frame 0141 complete. Cell density: 0.233
# Frame 0142 complete. Cell density: 0.234
# Frame 0143 complete. Cell density: 0.236
# Frame 0144 complete. Cell density: 0.238
# Frame 0145 complete. Cell density: 0.240
# Frame 0146 complete. Cell density: 0.242
# Frame 0147 complete. Cell density: 0.244
# Frame 0148 complete. Cell density: 0.246
# Frame 0149 complete. Cell density: 0.247
# Frame 0150 complete. Cell density: 0.249
# Frame 0151 complete. Cell density: 0.251
